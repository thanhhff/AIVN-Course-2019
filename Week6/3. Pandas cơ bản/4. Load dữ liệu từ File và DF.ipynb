# %% [markdown]
# Xử lý bảng dữ liệu cổ phiếu của Yahoo cung cấp!

# %%
import pandas as pd

# Load Google stock data in a DataFrame
Google_stock = pd.read_csv('GOOG.csv')

# Print some information about Google_stock
print('Google_stock is of type:', type(Google_stock))
# Out:
# Google_stock is of type: <class 'pandas.core.frame.DataFrame'>

# %%
print('Google_stock has shape:', Google_stock.shape)
# Out:
# Google_stock has shape: (251, 7)

# %%
Google_stock
# Out:
#            Date         Open         High          Low        Close  \
# 0    2018-08-22  1200.000000  1211.839966  1199.000000  1207.329956
# 1    2018-08-23  1207.140015  1221.280029  1204.239990  1205.380005
# 2    2018-08-24  1208.819946  1221.650024  1206.359009  1220.650024
# 3    2018-08-27  1227.599976  1243.089966  1225.715942  1241.819946
# 4    2018-08-28  1241.290039  1242.545044  1228.689941  1231.150024
# ..          ...          ...          ...          ...          ...
# 246  2019-08-15  1163.500000  1175.839966  1162.109985  1167.260010
# 247  2019-08-16  1179.550049  1182.719971  1171.810059  1177.599976
# 248  2019-08-19  1190.089966  1206.989990  1190.089966  1198.449951
# 249  2019-08-20  1195.250000  1196.060059  1182.109985  1182.689941
# 250  2019-08-21  1193.150024  1199.000000  1187.430054  1191.250000
#
#        Adj Close   Volume
# 0    1207.329956   887400
# 1    1205.380005   992600
# 2    1220.650024   946600
# 3    1241.819946  1156300
# ...

# %% [markdown]
# Thông thường dữ liệu rất dài, chúng ta muốn xem 1 số đại diện coi nó ra sao thì có 2 lệnh: `.head(N)` và `.tail(N)` để show số dòng N đầu tiên hoặc cuối cùng (mặc định N = 5)

# %%
Google_stock.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2018-08-22  1200.000000  1211.839966  1199.000000  1207.329956
# 1  2018-08-23  1207.140015  1221.280029  1204.239990  1205.380005
# 2  2018-08-24  1208.819946  1221.650024  1206.359009  1220.650024
# 3  2018-08-27  1227.599976  1243.089966  1225.715942  1241.819946
# 4  2018-08-28  1241.290039  1242.545044  1228.689941  1231.150024
#
#      Adj Close   Volume
# 0  1207.329956   887400
# 1  1205.380005   992600
# 2  1220.650024   946600
# 3  1241.819946  1156300
# 4  1231.150024  1304000
